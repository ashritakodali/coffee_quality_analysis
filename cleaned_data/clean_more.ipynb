# %% [markdown]
# <a href="https://colab.research.google.com/github/ashritakodali/coffee_quality_analysis/blob/main/cleaned_data/clean_more.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data cleaning, continued
#
# Data cleaning as appropriate for this specific analysis

# %%
import pandas as pd
import numpy as np

arabica = pd.read_csv()
